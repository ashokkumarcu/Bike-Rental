# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("C:/Users/Admin/Downloads/Bike Data/train.csv", sep = ';')

# %%
df_train.head()
# Out:
#    id  year  hour  season  holiday  workingday  weather   temp   atemp  \
# 0   3  2012    23       3        0           0        2  23.78  27.275
# 1   4  2011     8       3        0           0        1  27.88  31.820
# 2   5  2012     2       1        0           1        1  20.50  24.240
# 3   7  2011    20       3        0           1        3  25.42  28.790
# 4   8  2011    17       3        0           1        3  26.24  28.790
#
#    humidity  windspeed  count
# 0        73    11.0014    133
# 1        57     0.0000    132
# 2        59     0.0000     19
# 3        83    19.9995     58
# 4        89     0.0000    285

# %%
df_test  = pd.read_csv("C:/Users/Admin/Downloads/Bike Data/test.csv", sep = ';')

# %%
df_test.head()
# Out:
#    Unnamed: 0  year  hour  season  holiday  workingday  weather   temp  \
# 0           1  2012    21       3        0           0        1  29.52
# 1           2  2012     3       2        0           0        1  23.78
# 2           6  2011    10       1        0           1        3  16.40
# 3          14  2012    19       1        0           1        1  13.94
# 4          17  2011    23       3        0           1        2  26.24
#
#     atemp  humidity  windspeed
# 0  34.850        79     6.0032
# 1  27.275        83     0.0000
# 2  20.455         0    11.0014
# 3  15.150        46    19.9995
# 4  30.305        73    11.0014

# %%
df_train.set_index('id', inplace =True)

# %%
df_test.set_index('Unnamed: 0', inplace =True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7689 entries, 3 to 10886
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        7689 non-null   int64
#  1   hour        7689 non-null   int64
#  2   season      7689 non-null   int64
#  3   holiday     7689 non-null   int64
#  4   workingday  7689 non-null   int64
#  5   weather     7689 non-null   int64
#  6   temp        7689 non-null   float64
#  7   atemp       7689 non-null   float64
#  8   humidity    7689 non-null   int64
#  9   windspeed   7689 non-null   float64
#  10  count       7689 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 720.8 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3196 entries, 1 to 10874
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        3196 non-null   int64
#  1   hour        3196 non-null   int64
#  2   season      3196 non-null   int64
#  3   holiday     3196 non-null   int64
#  4   workingday  3196 non-null   int64
#  5   weather     3196 non-null   int64
#  6   temp        3196 non-null   float64
#  7   atemp       3196 non-null   float64
#  8   humidity    3196 non-null   int64
#  9   windspeed   3196 non-null   float64
# dtypes: float64(3), int64(7)
# memory usage: 274.7 KB

# %%
df_train.columns
# Out:
# Index(['year', 'hour', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'count'],
#       dtype='object')

# %%
df_train = df_train.astype('float')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7689 entries, 3 to 10886
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        7689 non-null   float64
#  1   hour        7689 non-null   float64
#  2   season      7689 non-null   float64
#  3   holiday     7689 non-null   float64
#  4   workingday  7689 non-null   float64
#  5   weather     7689 non-null   float64
#  6   temp        7689 non-null   float64
#  7   atemp       7689 non-null   float64
#  8   humidity    7689 non-null   float64
#  9   windspeed   7689 non-null   float64
#  10  count       7689 non-null   float64
# dtypes: float64(11)
# memory usage: 720.8 KB

# %%
df_test = df_test.astype('float')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3196 entries, 1 to 10874
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        3196 non-null   float64
#  1   hour        3196 non-null   float64
#  2   season      3196 non-null   float64
#  3   holiday     3196 non-null   float64
#  4   workingday  3196 non-null   float64
#  5   weather     3196 non-null   float64
#  6   temp        3196 non-null   float64
#  7   atemp       3196 non-null   float64
#  8   humidity    3196 non-null   float64
#  9   windspeed   3196 non-null   float64
# dtypes: float64(10)
# memory usage: 274.7 KB

# %%
sns.countplot(x = df_train['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
plt.figure(figsize = (10,10))
sns.countplot(x = df_train['hour'])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
sns.countplot(x = df_train['season'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
sns.countplot(x = df_train['holiday'])
# Out:
# <AxesSubplot:xlabel='holiday', ylabel='count'>

# %%
sns.countplot(x = df_train['workingday'])
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %%
sns.countplot(x = df_train['weather'])
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
sns.distplot(x = df_train['temp'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x = df_train['atemp'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x = df_train['humidity'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x = df_train['windspeed'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(df_train)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train = df_train.drop(columns = 'count')

# %%
y_train = df_train['count']

# %%
X_test = df_test

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (7689, 10)
# (3196, 10)
# (7689,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X_train_ss= ss.fit_transform(X_train)

# %%
X_test_ss = ss.transform(X_test)

# %%
reg = RandomForestRegressor(n_estimators=100,
                       random_state=45,
                       )

# %%
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=45)

# %%
y_pred_t = reg.predict(X_train)

# %%
reg.predict(X_test)
# Out:
# array([204.52,  29.2 ,  40.2 , ..., 384.61,  46.56,  84.44])

# %%
reg.fit(X_train_ss,y_train)
# Out:
# RandomForestRegressor(random_state=45)

# %%
y_pred_t_ss = reg.predict(X_train_ss)

# %%
reg.predict(X_test_ss)
# Out:
# array([204.52,  29.17,  40.2 , ..., 384.61,  47.38,  84.44])

# %%
from sklearn import metrics

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_train,y_pred_t)

# %%
mae
# Out:
# 10.851256375320755

# %%
mae_ss = mean_absolute_error(y_train, y_pred_t_ss)

# %%
mae_ss
# Out:
# 10.840145899006412
